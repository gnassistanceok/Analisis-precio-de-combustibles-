# %% [markdown]
# TRABAJO PRÁCTICO: HERRAMIENTAS PARA EL ANÁLISIS DE DATOS

# %% [markdown]
# # Importación de librerías a utilizar

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# #Importación de Dataset

# %%
data_set_pc=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/precios-en-surtidor-resolucin-3142016.csv')

# %%
data_set_pc
# Out:
#       indice_tiempo  idempresa           cuit               empresa  \
# 0           2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 1           2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 2           2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 3           2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 4           2026-04       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# ...             ...        ...            ...                   ...
# 36754       2026-05       4097  30-70795820-7           ZUSICO S.A.
# 36755       2025-08       4097  30-70795820-7           ZUSICO S.A.
# 36756       2025-08       4097  30-70795820-7           ZUSICO S.A.
# 36757       2026-05       4097  30-70795820-7           ZUSICO S.A.
# 36758       2026-05       4097  30-70795820-7           ZUSICO S.A.
#
#              direccion          localidad     provincia    region  idproducto  \
# 0      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 1      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 2      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 3      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 4      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           6
# ...                ...                ...           ...       ...         ...
# 36754  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           6
# 36755  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           3
# 36756  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           3
# 36757  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           2
# 36758  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           2
#
#                                producto  idtipohorario tipohorario  precio  \
# 0                       Gas Oil Grado 2              2      Diurno  2190.0
# 1                       Gas Oil Grado 2              3    Nocturno  2190.0
# 2                       Gas Oil Grado 3              2      Diurno  2478.0
# 3                       Gas Oil Grado 3              3    Nocturno  2479.0
# 4                                   GNC              2      Diurno   599.9
# ...                                 ...            ...         ...     ...
# 36754                               GNC              3    Nocturno  1049.0
# 36755  Nafta (premium) de más de 95 Ron              2      Diurno  1757.0
# 36756  Nafta (premium) de más de 95 Ron              3    Nocturno  1757.0
# 36757   Nafta (súper) entre 92 y 95 Ron              2      Diurno  2178.0
# 36758   Nafta (súper) entre 92 y 95 Ron              3    Nocturno  2178.0
#
#             fecha_vigencia  idempresabandera empresabandera    latitud  \
# 0      2026-05-01 12:43:00                28           PUMA -34.658476
# 1      2026-05-01 12:43:00                28           PUMA -34.658476
# 2      2026-05-01 12:44:00                28           PUMA -34.658476
# 3      2026-05-01 12:44:00                28           PUMA -34.658476
# 4      2026-04-02 14:09:00                28           PUMA -34.658476
# ...                    ...               ...            ...        ...
# 36754  2026-05-18 10:00:00                28           PUMA -38.031169
# 36755  2025-08-02 09:00:00                28           PUMA -38.031169
# 36756  2025-08-02 09:00:00                28           PUMA -38.031169
# 36757  2026-05-15 09:00:00                28           PUMA -38.031169
# 36758  2026-05-15 09:00:00                28           PUMA -38.031169
#
#         longitud                                            geojson
# 0     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# 1     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# 2     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# 3     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# 4     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# ...          ...                                                ...
# 36754 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
# 36755 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
# 36756 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
# 36757 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
# 36758 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
#
# [36759 rows x 19 columns]

# %% [markdown]
# ## Visualización general: cantidad de columnas y filas

# %%
data_set_pc.shape
# Out:
# (36759, 19)

# %% [markdown]
# ## Información general del Dataset

# %%
data_set_pc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36759 entries, 0 to 36758
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   indice_tiempo     36759 non-null  object
#  1   idempresa         36759 non-null  int64
#  2   cuit              36759 non-null  object
#  3   empresa           36759 non-null  object
#  4   direccion         36759 non-null  object
#  5   localidad         36759 non-null  object
#  6   provincia         36759 non-null  object
#  7   region            28788 non-null  object
#  8   idproducto        36759 non-null  int64
#  9   producto          36759 non-null  object
#  10  idtipohorario     36759 non-null  int64
#  11  tipohorario       36759 non-null  object
#  12  precio            36759 non-null  float64
#  13  fecha_vigencia    36759 non-null  object
#  14  idempresabandera  36759 non-null  int64
#  15  empresabandera    36759 non-null  object
#  16  latitud           36733 non-null  float64
#  17  longitud          36733 non-null  float64
#  18  geojson           36733 non-null  object
# dtypes: float64(3), int64(4), object(12)
# memory usage: 5.3+ MB

# %% [markdown]
# ### Tipos de datos del Dataset

# %%
data_set_pc.dtypes
# Out:
# indice_tiempo        object
# idempresa             int64
# cuit                 object
# empresa              object
# direccion            object
# localidad            object
# provincia            object
# region               object
# idproducto            int64
# producto             object
# idtipohorario         int64
# tipohorario          object
# precio              float64
# fecha_vigencia       object
# idempresabandera      int64
# empresabandera       object
# latitud             float64
# longitud            float64
# geojson              object
# dtype: object

# %% [markdown]
# ### Descripción general del Dataset

# %%
data_set_pc.describe()
# Out:
#           idempresa    idproducto  idtipohorario        precio  \
# count  36759.000000  36759.000000   36759.000000  36759.000000
# mean    5553.796104     10.732963       2.500014   1460.834187
# std     3413.933124      8.477581       0.500007    602.430246
# min      104.000000      2.000000       2.000000      6.999000
# 25%     2333.000000      3.000000       2.000000   1245.000000
# 50%     5748.000000      6.000000       3.000000   1435.000000
# 75%     8471.000000     19.000000       3.000000   1760.000000
# max    11501.000000     21.000000       3.000000   3000.000000
#
#        idempresabandera       latitud      longitud
# count      36759.000000  36733.000000  36733.000000
# mean           8.944068    -33.416583    -61.603435
# std           10.775520      4.108302      3.622760
# min           -1.000000    -54.829501    -72.338930
# 25%            2.000000    -34.804110    -64.268935
# 50%            4.000000    -34.062579    -60.672217
# 75%           26.000000    -31.444160    -58.552110
# max           30.000000    -22.055820    -53.648260

# %% [markdown]
# Al analizar la madia y la mediana, podemos observar que, en general, el grupo de datos es homogeneo ya que no hay diferencias significativas entre estas dos variables

# %% [markdown]
# # Preguntas para el análisis del dataset:
# 1) ¿Cuál es la variación del precio de los combustibles según el momento del día (mañana, tarde o noche) en que se realiza la carga?
# 2) ¿Cuál es la variación del precio de los combustibles según la empresa de bandera?
# 3) ¿Cuál es el precio promedio de cada tipo de combustible?

# %% [markdown]
# Lo primero que voy a hacer es eliminar las columnas que no voy a utilizar para el analsis. En este caso la latitud y longitud

# %%
data_set_pc = data_set_pc.drop(columns=['latitud', 'longitud'])

# %%
data_set_pc.head(5)
# Out:
#   indice_tiempo  idempresa           cuit               empresa  \
# 0       2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 1       2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 2       2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 3       2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 4       2026-04       1376  33-64337382-9  10 DE SETIEMBRE S.A.
#
#          direccion          localidad     provincia    region  idproducto  \
# 0  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 1  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 2  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 3  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 4  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           6
#
#           producto  idtipohorario tipohorario  precio       fecha_vigencia  \
# 0  Gas Oil Grado 2              2      Diurno  2190.0  2026-05-01 12:43:00
# 1  Gas Oil Grado 2              3    Nocturno  2190.0  2026-05-01 12:43:00
# 2  Gas Oil Grado 3              2      Diurno  2478.0  2026-05-01 12:44:00
# 3  Gas Oil Grado 3              3    Nocturno  2479.0  2026-05-01 12:44:00
# 4              GNC              2      Diurno   599.9  2026-04-02 14:09:00
#
#    idempresabandera empresabandera  \
# 0                28           PUMA
# 1                28           PUMA
# 2                28           PUMA
# 3                28           PUMA
# 4                28           PUMA
#
#                                              geojson
# 0  {"type":"Point","coordinates":[-58.529443,-34....
# 1  {"type":"Point","coordinates":[-58.529443,-34....
# 2  {"type":"Point","coordinates":[-58.529443,-34....
# 3  {"type":"Point","coordinates":[-58.529443,-34....
# 4  {"type":"Point","coordinates":[-58.529443,-34....

# %%
data_set_pc = data_set_pc.drop(columns=['idempresabandera','geojson','fecha_vigencia','idtipohorario','direccion'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_660/62239822.py in <cell line: 0>()
# ----> 1 data_set_pc = data_set_pc.drop(columns=['idempresabandera','geojson','fecha_vigencia','idtipohorario','direccion'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['idempresabandera', 'geojson', 'fecha_vigencia', 'idtipohorario', 'direccion'] not found in axis"

# %%
data_set_pc.head()
# Out:
#      fecha  idempresa           cuit          razon social          localidad  \
# 0  2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
# 1  2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
# 2  2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
# 3  2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
# 4  2026-04       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
#
#       provincia    region  idproducto         producto tipohorario  precio  \
# 0  BUENOS AIRES  PAMPEANA          19  Gas Oil Grado 2      Diurno  2190.0
# 1  BUENOS AIRES  PAMPEANA          19  Gas Oil Grado 2    Nocturno  2190.0
# 2  BUENOS AIRES  PAMPEANA          21  Gas Oil Grado 3      Diurno  2478.0
# 3  BUENOS AIRES  PAMPEANA          21  Gas Oil Grado 3    Nocturno  2479.0
# 4  BUENOS AIRES  PAMPEANA           6              GNC      Diurno   599.9
#
#   nombre_comercial
# 0             PUMA
# 1             PUMA
# 2             PUMA
# 3             PUMA
# 4             PUMA

# %% [markdown]
# Voy a contar cuantos surtidores se relevaron teniendo en cuenta la emrpesa de bandera

# %%
data_set_pc['nombre_comercial'].value_counts()
# Out:
# nombre_comercial
# YPF                      13206
# SHELL C.A.P.S.A.          7841
# AXION                     4775
# BLANCA                    4711
# PUMA                      3538
# DAPSA S.A.                1030
# GULF                       826
# REFINOR                    538
# VOY                        280
# OIL COMBUSTIBLES S.A.       10
# SIN EMPRESA BANDERA          4
# Name: count, dtype: int64

# %%
data_set_pc.duplicated().sum()
# Out:
# np.int64(32)

# %% [markdown]
# Entiendo que esto significa que no hay duplicados.

# %% [markdown]
# Voy a sacar valores nulos

# %%
data_set_pc.isnull().sum()
# Out:
# fecha                  0
# idempresa              0
# cuit                   0
# razon social           0
# localidad              0
# provincia              0
# region              7971
# idproducto             0
# producto               0
# tipohorario            0
# precio                 0
# nombre_comercial       0
# dtype: int64

# %% [markdown]
# Entiendo que en la columna "region" hay 7971 datos nulos, pero como no es una variable a analizar, no lo tengo en cuenta.

# %% [markdown]
# Voy a buscar datos duplicados

# %%
data_set_pc.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36754    False
# 36755    False
# 36756    False
# 36757    False
# 36758    False
# Length: 36759, dtype: bool

# %% [markdown]
# No hay ningún dato duplicado

# %% [markdown]
# Voy a cambiarle el nombre a algunas columnas, para que sea más facil identificar a que hacen referencia los datos que contienen

# %%
data_set_pc = data_set_pc.rename(columns={"indice_tiempo": "fecha", "empresa":"razon social", "empresabandera":"nombre_comercial"})
print("Columns after renaming:", data_set_pc.columns.tolist())
# Out:
# Columns after renaming: ['fecha', 'idempresa', 'cuit', 'razon social', 'localidad', 'provincia', 'region', 'idproducto', 'producto', 'tipohorario', 'precio', 'nombre_comercial']

# %%
data_set_pc.head(5)
# Out:
#      fecha  idempresa           cuit          razon social          localidad  \
# 0  2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
# 1  2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
# 2  2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
# 3  2026-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
# 4  2026-04       1376  33-64337382-9  10 DE SETIEMBRE S.A.  LOMAS DEL MIRADOR
#
#       provincia    region  idproducto         producto tipohorario  precio  \
# 0  BUENOS AIRES  PAMPEANA          19  Gas Oil Grado 2      Diurno  2190.0
# 1  BUENOS AIRES  PAMPEANA          19  Gas Oil Grado 2    Nocturno  2190.0
# 2  BUENOS AIRES  PAMPEANA          21  Gas Oil Grado 3      Diurno  2478.0
# 3  BUENOS AIRES  PAMPEANA          21  Gas Oil Grado 3    Nocturno  2479.0
# 4  BUENOS AIRES  PAMPEANA           6              GNC      Diurno   599.9
#
#   nombre_comercial
# 0             PUMA
# 1             PUMA
# 2             PUMA
# 3             PUMA
# 4             PUMA

# %% [markdown]
#  El dataset: Precio de combustible por región
#
# Cada fila es **una variedad de combustible**:
#
# | Columna | Significado | Tipo de variable |
# |---|---|---|
# | `fecha` | Fecha de medición | Numérica |
# | `idempresa` | Numero de ID de la empresa | Numérica |
# | `CUIT` | Numero de CUIT | Numérica |
# | `razon social` | Razon social | Categórica |
# | `Producto` | Variedad de combustible | Categórica |
# | `Tipohorario` | Momento del dia de carga | Categorica |
# | `precio` | Valor del combustible | Numérica |
# | `nombre_comercial` | Empresa a la que pertenece | Categórica |

# %% [markdown]
# Productos y su frecuencia

# %%
product_counts = data_set_pc['producto'].value_counts()
display(product_counts)
# Out:
# producto
# Gas Oil Grado 2                     8372
# Nafta (súper) entre 92 y 95 Ron     8348
# Gas Oil Grado 3                     8194
# Nafta (premium) de más de 95 Ron    8125
# GNC                                 3720
# Name: count, dtype: int64

# %% [markdown]
# Precios Promedio de los Productos
# A continuación, calcularemos el precio promedio para cada tipo de combustible en el dataset.

# %%
average_prices = data_set_pc.groupby('producto')['precio'].mean().reset_index()
average_prices = average_prices.sort_values(by='precio', ascending=False)
display(average_prices)
# Out:
#                            producto       precio
# 2                   Gas Oil Grado 3  1678.583619
# 3  Nafta (premium) de más de 95 Ron  1644.660794
# 1                   Gas Oil Grado 2  1473.804205
# 4   Nafta (súper) entre 92 y 95 Ron  1428.525276
# 0                               GNC   623.011543

# %%
average_prices['precio'] = average_prices['precio'].round(2)
display(average_prices)
# Out:
#                            producto   precio
# 2                   Gas Oil Grado 3  1678.58
# 3  Nafta (premium) de más de 95 Ron  1644.66
# 1                   Gas Oil Grado 2  1473.80
# 4   Nafta (súper) entre 92 y 95 Ron  1428.53
# 0                               GNC   623.01

# %% [markdown]
# # Análisis gráfico

# %% [markdown]
# Gráfico de Barras de Precios Promedio por Producto
# Este gráfico de barras muestra el precio promedio de cada tipo de combustible, lo que facilita la comparación visual entre ellos.

# %%
fig = px.bar(average_prices, x='producto', y='precio',
             title='Precios Promedio por Tipo de Producto',
             labels={'producto': 'Tipo de Producto', 'precio': 'Precio Promedio'},
             color='producto', # Colorea las barras por producto
             template='plotly_white') # Utiliza un tema limpio

# %%
fig.update_layout(xaxis_title_standoff=25) # Ajusta el espaciado del título del eje X
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="749d7620-c25a-4e95-84e1-a5b77b8f9e12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("749d7620-c25a-4e95-84e1-a5b77b8f9e12")) {                    Plotly.newPlot(                        "749d7620-c25a-4e95-84e1-a5b77b8f9e12",                        [{"alignmentgroup":"True","hovertemplate":"Tipo de Producto=%{x}\u003cbr\u003ePrecio Promedio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas Oil Grado 3","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Gas Oil Grado 3","offsetgroup":"Gas Oil Grado 3","orientation":"v","showlegend":true,"textposition":"auto","x":["Gas Oil Grado 3"],"xaxis":"x","y":[1678.58],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo de Producto=%{x}\u003cbr\u003ePrecio Promedio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nafta (premium) de más de 95 Ron","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Nafta (premium) de más de 95 Ron","offsetgroup":"Nafta (premium) de más de 95 Ron","orientation":"v","showlegend":true,"textposition":"auto","x":["Nafta (premium) de más de 95 Ron"],"xaxis":"x","y":[1644.66],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo de Producto=%{x}\u003cbr\u003ePrecio Promedio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas Oil Grado 2","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Gas Oil Grado 2","offsetgroup":"Gas Oil Grado 2","orientation":"v","showlegend":true,"textposition":"auto","x":["Gas Oil Grado 2"],"xaxis":"x","y":[1473.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo de Producto=%{x}\u003cbr\u003ePrecio Promedio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nafta (súper) entre 92 y 95 Ron","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Nafta (súper) entre 92 y 95 Ron","offsetgroup":"Nafta (súper) entre 92 y 95 Ron","orientation":"v","showlegend":true,"textposition":"auto","x":["Nafta (súper) entre 92 y 95 Ron"],"xaxis":"x","y":[1428.53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tipo de Producto=%{x}\u003cbr\u003ePrecio Promedio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GNC","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"GNC","offsetgroup":"GNC","orientation":"v","showlegend":true,"textposition":"auto","x":["GNC"],"xaxis":"x","y":[623.01],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[ ...

# %% [markdown]
# Por lo que puedo interpretar, el Gas Oil Grado 3 y la Nafta Premium tienen casi el mismo valor, asi como el Gas Oil Grado 2 y la Nafta Super. El GNC es el producto de menor valor, por lo que explica que los automoviles que se utilizan para trabajr (taxis, aplicaciones, etc) utilicen este combustible para abaratar sus costos.

# %% [markdown]
# Histograma Interactivo de Precios por Momento del Día (Plotly)
# Este histograma interactivo, generado con Plotly, permite explorar la distribución de los precios de combustible (precio) para cada momento del día (tipohorario).

# %%
fig = px.histogram(data_set_pc, y='tipohorario', x='precio',
                   title='Distribución Interactiva de Precios de Combustible por Momento del Día',
                   labels={'precio': 'Precio del Combustible', 'tipohorario': 'Momento del Día de Carga'},
                   histnorm='density', # o 'count' si prefieres la cuenta de observaciones
                   nbins=50, # Número de "contenedores" en el histograma
                   marginal='box', # Añade un boxplot marginal para cada grupo
                   orientation='h') # Orientación horizontal para el histograma

# %%
fig.update_layout(bargap=0.1) # Espacio entre las barras
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="37749c69-e2cb-4983-b0fe-c7c3b00d2c9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37749c69-e2cb-4983-b0fe-c7c3b00d2c9e")) {                    Plotly.newPlot(                        "37749c69-e2cb-4983-b0fe-c7c3b00d2c9e",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","histnorm":"density","hovertemplate":"density weighted by Precio del Combustible=%{x}\u003cbr\u003eMomento del Día de Carga=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsy":50,"offsetgroup":"","orientation":"h","showlegend":false,"x":[2190.0,2190.0,2478.0,2479.0,599.9,599.9,2347.0,2347.0,2136.0,2136.0,1236.0,1236.0,1480.0,1480.0,1220.0,1220.0,1026.0,1026.0,1220.0,1220.0,1467.0,1467.0,1220.0,1220.0,1026.0,1026.0,2222.0,2222.0,2504.0,2504.0,699.0,699.0,2466.0,2466.0,2194.0,2194.0,1370.0,1370.0,1560.0,1560.0,1590.0,1590.0,1370.0,1370.0,1259.0,1259.0,1414.0,1414.0,727.0,727.0,1454.0,1454.0,1237.0,1237.0,1748.0,1748.0,2031.0,2031.0,1975.0,1975.0,1697.0,1697.0,2188.0,2188.0,2470.0,2470.0,669.0,669.0,2391.0,2391.0,2099.0,2098.0,1250.0,1250.0,1425.0,1425.0,1218.0,1218.0,1000.0,1000.0,1281.0,1281.0,1543.0,1543.0,1575.0,1575.0,1283.0,1283.0,1450.0,1450.0,744.0,744.0,1450.0,1450.0,1393.0,1393.0,1515.0,1515.0,1482.0,1482.0,1241.0,1241.0,862.0,862.0,993.0,993.0,983.0,983.0,794.0,794.0,1282.0,1282.0,1483.0,1483.0,639.0,639.0,1520.0,1520.0,1249.0,1249.0,1149.0,1149.0,1364.0,1364.0,720.0,720.0,1050.0,1050.0,852.0,852.0,2259.0,2259.0,2489.0,2489.0,795.0,795.0,2399.0,2399.0,2179.0,2179.0,2465.0,2465.0,2538.0,2538.0,2438.0,2438.0,2179.0,2179.0,1221.0,1221.0,1403.0,1403.0,1460.0,1460.0,1248.0,1248.0,1221.0,1221.0,1403.0,1403.0,639.0,639.0,1460.0,1460.0,1248.0,1248.0,2357.0,2357.0,2604.0,2604.0,949.0,949.0,2448.0,2448.0,2219.0,2219.0,1780.0,1780.0,1959.0,1959.0,749.0,749.0,1919.0,1919.0,1629.0,1629.0,22.99,22.99,25.99,25.99,27.99,27.99,25.49,25.49,1267.0,1267.0,1420.0,1420.0,1509.0,1509.0,1311.0,1311.0,2236.0,2236.0,2380.0,2380.0,2308.0,2308.0,2088.0,2088.0,1244.0,1244.0,1375.0,1375.0,1388.0,1388.0,1185.0,1185.0,1195.0,1195.0,1375.0,1375.0,1435.0,1435.0,1215.0,1215.0,1195.0,1195.0,1375.0,1375.0,1435.0,1435.0,1215.0,1215.0,1277.0,1277.0,1414.0,1414.0,839.0,839.0,1454.0,1454.0,1266.0,1266.0,1412.0,1412.0,1599.0,1599.0,698.0,698.0,1553.0,1553.0,1345.0,1345.0,1291.0,1291.0,1427.0,1427.0,1479.0,1479.0,1284.0,1284.0,2160.0,2160.0,2385.0,2385.0,669.0,669.0,2242.0,2242.0,2074.0,2074.0,1380.0,1380.0,1815.0,1815.0,698.0,698.0,1540.0,1540.0,1291.0,1291.0,1427.0,1427.0,33.98,33.98,1479.0,1479.0,1284.0,1284.0,116.9,116.9,90.4,90.4,145.8,145.8,121.9,121.9,2319.0,2319.0,2587.0,2587.0,980.0,980.0,2457.0,2457.0,2172.0,2172.0,1309.0,1309.0,1454.0,1454.0,1474.0,1474.0,1276.0,1276.0,697.0,697.0,1818.0,1818.0,1952.0,1952.0,790.0,790.0,1926.0,1926.0,1666.0,1666.0,1424.0,1424.0,1952.0,1952.0,790.0,790.0,1926.0,1926.0,1666.0,1666.0,1818.0,1818.0,1952.0,1952.0,789.0,789.0,1926.0,1926.0,1666.0,1666.0,1959.0,1959.0,2099.0,2099.0,679.0,679.0,2049.0,2049.0,1809.0,1809.0,1304.0,1304.0,1489.0,1489.0,1486.0,1486.0,1288.0,1288.0,1304.0,1304.0,1489.0,1489.0,1486.0,1486.0,1288.0,1288.0,1304.0,1304.0,1489.0,1489.0,1486.0,1486.0,1288.0,1288.0,1304.0,1304.0,1489.0,1489.0,1486.0,1486.0,1288.0,1288.0,1304.0,1304.0,1489.0,1489.0,1486.0,1486.0,1288.0,1288.0,1304.0,1304.0,1489.0,1489.0,1486.0,1486.0,1288.0,1288.0,1221.0,1221.0,1402.0,1402.0,449.0,449.0,1461.0,1461.0,1248.0,1248.0,1207.0,1207.0,1386.0,1386.0,429.0,429.0,1444.0,1444.0,1233.0,1233.0,255.9,255.9,325.0,325.0,110.7,110.7,280.7,280.7,228.3,228.3,999.0,999.0,200.0,200.0,368.3,368.3,443.0,443.0,393.2,393.2,312.3,312.3,1368.0,1368.0,1498.0, ...

# %% [markdown]
# Por lo que interpreto, no varia el precio del combustible de manera significativa, segun el momento del día

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=data_set_pc, x='nombre_comercial', y='precio', palette='viridis')
plt.title('Distribución de Precios de Combustible según nombre_comercial')
plt.xlabel('nombre_comercial')
plt.ylabel('Precio')
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor lectura
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_660/70787720.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Se puede ver que las marcas que tienen cajas mas grandes tienen mayor variación de precios, mientras que los que tienen cajas mas chicas sus precios varian poco, aunque por ejemplo YPF, posee muchos valores outliers, lo que indica que posee muchos valores por arriba y debajo de los tipicos.
